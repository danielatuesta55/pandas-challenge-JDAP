# %% [markdown]
# Heroes Of Pymoli Challange

# %% [markdown]
# Part 1: I need to import dependencies

# %%
#Import dependencies 
import pandas as pd

# %% [markdown]
# Part 2: I need to Reference the file and import the data to pandas.

# %%
# Reference the file where the CSV is located
HeroesOfPymoli_csv_path = "Resources/purchase_data.csv"
# Import the data into a Pandas DataFrame
df = pd.read_csv(HeroesOfPymoli_csv_path)
df
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male       92
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# ...

# %% [markdown]
# Part 3: I need to count the unique total amount of players in the data set. I used the nunique function and saved it in the varibale Total_Number_Players

# %%
Total_Number_Players = df.SN.nunique()
print(Total_Number_Players)
# Out:
# 576

# %%
# i need to format this into a table
